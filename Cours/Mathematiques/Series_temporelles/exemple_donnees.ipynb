# %% [markdown]
# # Données climatologiques

# %% [markdown]
# ## base de 6 minutes

# %% [markdown]
# **Présentation :**
# Données climatologiques des stations de la Gironde pour le paramètre précipitation au pas temps 6 minutes. L'accès à toute la profondeur de la base de données est possible (depuis juillet 2005 au plus tôt).
#
# **Informations techniques**
# - Les données 6mn de précipitations sont proposées en téléchargement, par département et par lots de période au format csv compressé
# - La mise à jour des fichiers est annuelle pour les fichiers par décennie, mensuelles pour les fichiers de la décennie en cours jusqu'à l'année -2 et quotidiennes pour les deux dernières années
# - Les heures sont exprimées en UTC pour la métropole et en FU pour l'outre-mer

# %%
from pandas import read_csv, to_datetime, DataFrame #, read_json, json_normalize
from folium import Map, Marker

# %%
fichier = 'Q_33_previous-1950-2022_RR-T-Vent'
nom_num = 'NUM_POSTE'
nom_nom = 'NOM'
nom_date = 'DATE'
nom_donnee = 'TM'
nom_lat = 'LAT'
nom_lon = 'LON'
nom_format = '%Y%m%d'#%H%M%S'

# %% [markdown]
# ### Données

# %%
data_source = read_csv(fichier + '.csv', sep=";")
data_source
# Out:
#          NUM_POSTE        NOM_USUEL        LAT       LON  ALTI  AAAAMMJJ  \
# 0         33004001            AMBES  45.041667 -0.608333     5  19571215
# 1         33004001            AMBES  45.041667 -0.608333     5  19571216
# 2         33004001            AMBES  45.041667 -0.608333     5  19571217
# 3         33004001            AMBES  45.041667 -0.608333     5  19571218
# 4         33004001            AMBES  45.041667 -0.608333     5  19571219
# ...            ...              ...        ...       ...   ...       ...
# 1332318   33554001  YVRAC AERODROME  44.881667 -0.460000    77  19680327
# 1332319   33554001  YVRAC AERODROME  44.881667 -0.460000    77  19680328
# 1332320   33554001  YVRAC AERODROME  44.881667 -0.460000    77  19680329
# 1332321   33554001  YVRAC AERODROME  44.881667 -0.460000    77  19680330
# 1332322   33554001  YVRAC AERODROME  44.881667 -0.460000    77  19680331
#
#            RR  QRR  TN  QTN  ...  DXI2  QDXI2  HXI2  QHXI2  FXI3S  QFXI3S  \
# 0         0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 1         0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 2         0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 3        21.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 4         0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# ...       ...  ...  ..  ...  ...   ...    ...   ...    ...    ...     ...
# 1332318   0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 1332319   0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 1332320   0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 1332321   0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
# 1332322   0.0  1.0 NaN  NaN  ...   NaN    NaN   NaN    NaN    NaN     NaN
#
#          DXI3S  QDXI3S  HXI3S  QHXI3S
# 0          NaN     NaN    NaN     NaN
# 1          NaN     NaN    NaN     NaN
# 2          NaN     NaN    NaN     NaN
# 3          NaN     NaN    NaN     NaN
# 4          NaN     NaN    NaN     NaN
# ...        ...     ...    ...     ...
# 1332318    NaN     NaN    NaN     NaN
# 1332319    NaN     NaN    NaN     NaN
# 1332320    NaN     NaN    NaN     NaN
# 1332321    NaN     NaN    NaN     NaN
# 1332322    NaN     NaN    NaN     NaN
#
# [1332323 rows x 56 columns]

# %% [markdown]
# ### Colonnes

# %%
data_source.columns
# Out:
# Index(['NUM_POSTE', 'NOM_USUEL', 'LAT', 'LON', 'ALTI', 'AAAAMMJJ', 'RR', 'QRR',
#        'TN', 'QTN', 'HTN', 'QHTN', 'TX', 'QTX', 'HTX', 'QHTX', 'TM', 'QTM',
#        'TNTXM', 'QTNTXM', 'TAMPLI', 'QTAMPLI', 'TNSOL', 'QTNSOL', 'TN50',
#        'QTN50', 'DG', 'QDG', 'FFM', 'QFFM', 'FF2M', 'QFF2M', 'FXY', 'QFXY',
#        'DXY', 'QDXY', 'HXY', 'QHXY', 'FXI', 'QFXI', 'DXI', 'QDXI', 'HXI',
#        'QHXI', 'FXI2', 'QFXI2', 'DXI2', 'QDXI2', 'HXI2', 'QHXI2', 'FXI3S',
#        'QFXI3S', 'DXI3S', 'QDXI3S', 'HXI3S', 'QHXI3S'],
#       dtype='object')

# %%
data_colonne = data_source.copy()
data_colonne.columns = [nom_num, nom_nom, nom_lat, nom_lon, 'ALTI', nom_date, 'RR', 'QRR',
       nom_donnee, 'QTN', 'HTN', 'QHTN', 'TX', 'QTX', 'HTX', 'QHTX', 'TM', 'QTM',
       'TNTXM', 'QTNTXM', 'TAMPLI', 'QTAMPLI', 'TNSOL', 'QTNSOL', 'TN50',
       'QTN50', 'DG', 'QDG', 'FFM', 'QFFM', 'FF2M', 'QFF2M', 'FXY', 'QFXY',
       'DXY', 'QDXY', 'HXY', 'QHXY', 'FXI', 'QFXI', 'DXI', 'QDXI', 'HXI',
       'QHXI', 'FXI2', 'QFXI2', 'DXI2', 'QDXI2', 'HXI2', 'QHXI2', 'FXI3S',
       'QFXI3S', 'DXI3S', 'QDXI3S', 'HXI3S', 'QHXI3S']

# %%
data_colonne.dtypes
# Out:
# NUM_POSTE      int64
# NOM           object
# LAT          float64
# LON          float64
# ALTI           int64
# DATE           int64
# RR           float64
# QRR          float64
# TM           float64
# QTN          float64
# HTN          float64
# QHTN         float64
# TX           float64
# QTX          float64
# HTX          float64
# QHTX         float64
# TM           float64
# QTM          float64
# TNTXM        float64
# QTNTXM       float64
# TAMPLI       float64
# QTAMPLI      float64
# TNSOL        float64
# QTNSOL       float64
# TN50         float64
# QTN50        float64
# DG           float64
# QDG          float64
# FFM          float64
# QFFM         float64
# FF2M         float64
# QFF2M        float64
# FXY          float64
# QFXY         float64
# DXY          float64
# QDXY         float64
# HXY          float64
# QHXY         float64
# FXI          float64
# QFXI         float64
# DXI          float64
# QDXI         float64
# HXI          float64
# QHXI         float64
# FXI2         float64
# QFXI2        float64
# DXI2         float64
# QDXI2        float64
# HXI2         float64
# QHXI2        float64
# FXI3S        float64
# QFXI3S       float64
# DXI3S        float64
# QDXI3S       float64
# HXI3S        float64
# QHXI3S       float64
# dtype: object

# %%
data_select = data_colonne[[nom_num, nom_nom, nom_lat, nom_lon, nom_date, nom_donnee]]
data_select
# Out:
#          NUM_POSTE              NOM        LAT       LON      DATE  TM  TM
# 0         33004001            AMBES  45.041667 -0.608333  19571215 NaN NaN
# 1         33004001            AMBES  45.041667 -0.608333  19571216 NaN NaN
# 2         33004001            AMBES  45.041667 -0.608333  19571217 NaN NaN
# 3         33004001            AMBES  45.041667 -0.608333  19571218 NaN NaN
# 4         33004001            AMBES  45.041667 -0.608333  19571219 NaN NaN
# ...            ...              ...        ...       ...       ...  ..  ..
# 1332318   33554001  YVRAC AERODROME  44.881667 -0.460000  19680327 NaN NaN
# 1332319   33554001  YVRAC AERODROME  44.881667 -0.460000  19680328 NaN NaN
# 1332320   33554001  YVRAC AERODROME  44.881667 -0.460000  19680329 NaN NaN
# 1332321   33554001  YVRAC AERODROME  44.881667 -0.460000  19680330 NaN NaN
# 1332322   33554001  YVRAC AERODROME  44.881667 -0.460000  19680331 NaN NaN
#
# [1332323 rows x 7 columns]

# %% [markdown]
# ### Emplacement

# %%
data_select.set_index(nom_num, inplace = True)
data_select
# Out:
#                        NOM        LAT       LON      DATE  TM  TM
# NUM_POSTE
# 33004001             AMBES  45.041667 -0.608333  19571215 NaN NaN
# 33004001             AMBES  45.041667 -0.608333  19571216 NaN NaN
# 33004001             AMBES  45.041667 -0.608333  19571217 NaN NaN
# 33004001             AMBES  45.041667 -0.608333  19571218 NaN NaN
# 33004001             AMBES  45.041667 -0.608333  19571219 NaN NaN
# ...                    ...        ...       ...       ...  ..  ..
# 33554001   YVRAC AERODROME  44.881667 -0.460000  19680327 NaN NaN
# 33554001   YVRAC AERODROME  44.881667 -0.460000  19680328 NaN NaN
# 33554001   YVRAC AERODROME  44.881667 -0.460000  19680329 NaN NaN
# 33554001   YVRAC AERODROME  44.881667 -0.460000  19680330 NaN NaN
# 33554001   YVRAC AERODROME  44.881667 -0.460000  19680331 NaN NaN
#
# [1332323 rows x 6 columns]

# %%
liste_station_num = data_select.index.unique()
nombre_station = len(liste_station_num)
range_station = range(nombre_station)
liste_station_nom = [list(data_select.loc[index, nom_nom])[0] for index in liste_station_num]
data_stations = DataFrame(liste_station_nom, liste_station_num)

data_stations.head()
# Out:
#                                    0
# NUM_POSTE
# 33004001                       AMBES
# 33005001          ANDERNOS-LES-BAINS
# 33009001                    ARCACHON
# 33009002   ARCACHON LYCEE CLIMATIQUE
# 33009006                      BIOARC

# %%
### il doit etre a true
nombre_station == len(data_select[nom_nom].unique())
# Out:
# False

# %%
lat_max = data_colonne['LAT'].max()
lat_min = data_colonne['LAT'].min()
lon_max = data_colonne['LON'].max()
lon_min = data_colonne['LON'].min()
lat_centre = lat_min + (lat_max - lat_min) / 2
lon_centre = lon_min + (lon_max - lon_min) / 2

# %%
# data_station = read_json("stations_info-basiques.json")
# data_features = json_normalize(data_station['features'])
# data_features.columns = data_features.columns.str.replace('properties.', '')
# data_features.columns = data_features.columns.str.replace('geometry.', '')
# data_features.set_index(nom_num, inplace = True)
# data_features
# Out:
#               type   type                      coordinates  COMMUNE   ALTI  \
# NUM_POSTE
# NaN            NaN    NaN                              NaN      NaN    NaN
# NaN            NaN    NaN                              NaN      NaN    NaN
# 01014002   Feature  Point  [5.6690000000000005, 46.278167]   ARBENT  534.0
# 01027003   Feature  Point               [5.106667, 45.833]    BALAN  196.0
# 01028001   Feature  Point     [4.9045000000000005, 46.122]  BANEINS  243.0
# ...            ...    ...                              ...      ...    ...
# 98827002   Feature  Point         [165.002167, -21.318167]     POYA   82.0
# 98830002   Feature  Point           [165.2545, -20.789333]    TOUHO    2.0
# 98832002   Feature  Point              [166.939, -22.1565]     YATE   25.0
# 98832006   Feature  Point         [166.726333, -22.132667]     YATE  171.0
# 98832101   Feature  Point           [166.9675, -22.269167]     YATE  298.0
#
#                          NOM_USUEL     LAT_DG  NUM_DEP      LON_DG  \
# NUM_POSTE
# NaN                            NaN        NaN      NaN         NaN
# NaN                            NaN        NaN      NaN         NaN
# 01014002                    ARBENT  46.278167      1.0    5.669000
# 01027003                BALAN_AERO  45.833000      1.0    5.106667
# 01028001                   BANEINS  46.122000      1.0    4.904500
# ...                            ...        ...      ...         ...
# 98827002                    NEPOUI -21.318167    988.0  165.002167
# 98830002              TOUHO AEROD. -20.789333    988.0  165.254500
# 98832002                 YATE MRIE -22.156500    988.0  166.939000
# 98832006           RIVIERE BLANCHE -22.132667    988.0  166.726333
# 98832101   GORO_ANCIENNE_PEPINIERE -22.269167    988.0  166.967500
#
#            ficheClimComplete  ficheClimReduite
# NUM_POSTE
# NaN                      NaN               NaN
# NaN                      NaN               NaN
# 01014002                 0.0               1.0
# 01027003                 0.0               0.0
# 01028001                 0.0               1.0
# ...                      ...               ...
# 98827002                 1.0               1.0
# 98830002                 0.0               1.0
# 98832002                 0.0               1.0
# 98832006                 0.0               1.0
# 98832101                 0.0               1.0
#
# [2396 rows x 11 columns]

# %%
carte = Map(
    location = [lat_centre, lon_centre]
    , zoom_start = 9
)


for index in liste_station_num :
    Marker(
        location = [list(data_select.loc[index, 'LAT'])[0], list(data_select.loc[index, 'LON'])[0]]
        , popup = [index, list(data_select.loc[index, nom_nom])[0]]
    ).add_to(carte)

### si toute les station existe encore
# for index in liste_station_num :
#     if index in data_features.index :
#         Marker(
#             # location = data_features.loc[str(index), 'coordinates'][::-1]
#             # , popup = [index, data_features.loc[str(index)]]
#         ).add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce75fdb26a566799536452bc1948d2ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce75fdb26a566799536452bc1948d2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce75fdb26a566799536452bc1948d2ce = L.map(
#                 &quot;map_ce75fdb26a566799536452bc1948d2ce&quot;,
#                 {
#                     center: [44.9405835, -0.5085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02836e93450702214aa56c141b1094cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_02836e93450702214aa56c141b1094cd.addTo(map_ce75fdb26a566799536452bc1948d2ce);
#
#
#             var marker_811ae97216ee4d5771dd4dda123259b4 = L.marker(
#                 [45.041667, -0.608333],
#                 {}
#             ).addTo(map_ce75fdb26a566799536452bc1948d2ce);
#
#
#         var popup_008c9a7030fd2c330593e688b320f7b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_805245fd8389c1acdfe6454de9131e2b = $(`&lt;div id=&quot;html_805245fd8389c1acdfe6454de9131e2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[33004001, &#x27;AMBES&#x27;]&lt;/div&gt;`)[0];
#                 popup_008c9a7030fd2c330593e688b320f7b3.setContent(html_805245fd8389c1acdfe6454de9131e2b);
#
#
#
#         marker_811ae97216ee4d5771dd4dda123259b4.bindPopup(popup_008c9a7030fd2c330593e688b320f7b3)
#         ;
#
#
#
#
#             var marker_e7a07342e21e0b9e322f5078ba61d42f = L.marker(
#                 [44.741667, -1.096667],
#                 {}
#             ).addTo(map_ce75fdb26a566799536452bc1948d2ce);
#
#
#         var popup_3310ce277652a15610e1d0f2f3ef4fc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_225f609c51fdfa2db4f174db3d5cac48 = $(`&lt;div id=&quot;html_225f609c51fdfa2db4f174db3d5cac48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[33005001, &#x27;ANDERNOS-LES-BAINS&#x27;]&lt;/div&gt;`)[0];
#                 popup_3310ce277652a15610e1d0f2f3ef4fc1.setContent(html_225f609c51fdfa2db4f174db3d5cac48);
#
#
#
#         marker_e7a07342e21e0b9e322f5078ba61d42f.bindPopup(popup_3310ce277652a15610e1d0f2f3ef4fc1)
#         ;
#
#
#
#
#             var marker_136e019566f2db2aaadb9984936d2f76 = L.marker(
#                 [44.663333, -1.15],
#                 {}
#             ).addTo(map_ce75fdb26a566799536452bc1948d2ce);
#
#
#         var popup_76e0181fad4871537aded8274881cf98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3d09471a714dd8e37cd0fca0ce7da87 = $(`&lt;div id=&quot;html_e3d09471a714dd8e37cd0fca0ce7da87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[33009001, &#x27;ARCACHON&#x27;]&lt;/div&gt;`)[0];
#                 popup_76e0181fad4871537aded8274881cf98.setContent(html_e3d09471a714dd8e37cd0fca0ce7da87);
#
#
#
#         marker_136e019566f2db2aaadb9984936d2f76.bindPopup(popup_76e0181fad4871537aded8274881cf98)
#         ;
#
#
#
#
#             var marker_7dc34116f4d9b1756a01db19b1fde93b = L.marker(
#                 [44.658333, -1.17],
#                 {}
#             ).addTo(map_ce75fdb26a566799536452bc1948d2ce);
#
#
#         var popup_3b3f5329183841908509ada27c295062 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da578df063c99ce4e7bfebfe0bd41e6a = $(`&lt;div id=&quot;html_da578df063c99ce4e7bfebfe0bd41e6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[33009002, &#x27;ARCACHON LYCEE CLIMATIQUE&#x27;]&lt;/div&gt;`)[0];
#                 popup_3b3f5329183841908509ada27c295062.setContent(html_da578df063c99ce4e7bfebfe0bd41e6a);
#
#
#
#         marker_7dc34116f4d9b1756a01db19b1fde93b.bindPopup(popup_3b3f5329183841908509ada27c295062)
#         ;
#
#
#
#
#             var marker_1fad36f0d631a0f09efe5ede7d18aa5e = L.marker(
#                 [44.643333, -1.165],
#                 {}
#             ).addTo(map_ce75fdb26a566799536452bc1948d2ce);
#
#
#         var popup_0bce20554ef6b07b769667bbfab50d8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebbc4443f894eab3b75812e391595052 = $(`&lt;div id=&quot;html_ebbc4443f894eab3b75812e391595052&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[33009006, &#x27;BIOARC&#x27;]&lt;/div&gt;`)[0];
#                 popup_0bce20554ef6b07b769667bbfab50d8f.setContent(html_ebbc4443f894eab3b75812e391595052);
#
#
#
#         marker_1fad36f0d631a0f09efe5ede7d18aa5e.bindPopup(popup_0bce20554ef6b07b769667bbfab50d8f)
#         ;
#
#
#
#
#             var marker_d2cd502123385b7e88826fa78dc85671 = L.marker(
#                 [44.

# %% [markdown]
# ### Date

# %%
for index in range_station :
    data_test = data_select.loc[data_select.index==liste_station_num[index]]#, data_index['RR']!=0
    #data_test = data_test.loc[data_test[nom_donnee]!=0]
    print(liste_station_nom[index], liste_station_num[index], len(data_test))
# Out:
# AMBES 33004001 9138
# ANDERNOS-LES-BAINS 33005001 2223
# ARCACHON 33009001 18871
# ARCACHON LYCEE CLIMATIQUE 33009002 8095
# BIOARC 33009006 1743
# ARES 33011001 12692
# ARSAC 33012001 1675
# AUROS 33021002 16404
# LE BARP 33029001 12039
# BAYON SUR GIRON 33035001 4292
# BAZAS 33036001 17287
# BEGADAN 33038001 2160
# BELIN-BELIET 33042001 26663
# BELIN-BELIET JOUE 33042002 243
# BELIN-BELIET BOURG 33042004 4018
# BELIN BELIET 33042005 6118
# BEYCHAC ET CAIL 33049001 16770
# BIGANOS 33051001 21155
# BLANQUEFORT CUB 33056001 211
# BLANQUEFORT 33056002 2191
# BLASIMON 33057001 2191
# BOMME 33060001 1461
# BORDEAUX-PAULIN 33063001 26663
# BORDEAUX RUE DE LASEPPE 33063002 5992
# BORDEAUX QUAI BACALAN 33063003 7913
# BORDEAUX FARGUE 33063004 7210
# BORDEAUX JOURDE 33063006 5203
# BORDEAUX BASTIDE 33063007 242
# BOURG GAZIN 33067001 334
# BOURIDEYS 33068001 1356
# LE BOUSCAT 33069001 5378
# BRAUD ET ST LOU 33073001 5448
# BUDOS 33076001 20879
# CABANAC ET VILL 33077001 23679
# CABANAC ET VILL 33077002 15848
# CADAUJAC-INRA 33080001 13636
# CADILLAC AGGLOMERATION 33081001 211
# CAPTIEUX 33095001 26663
# CARCANS 33097001 10166
# CARCANS 33097002 6232
# CASTELVIEL SAE 33105001 30
# CAVIGNAC AGGLOMERATION 33114001 2130
# CAZATS 33116001 7550
# CAZAUGITAT 33117001 1430
# CENON 33119001 16498
# CESTAS HERMITAGE DE PIERROTON 33122001 8491
# CESTAS POT AU PIN 33122002 1352
# PIERROTON-INRA 33122003 7471
# CISSAC-MEDOC 33125002 7397
# COIRAC SAE 33131001 243
# COURS-DE-MONSEGUR GOBELET 33136001 486
# COUTRAS 33138001 18997
# CURSAN 33145001 15770
# CUSSAC 33146001 2191
# DIEULIVOL 33150001 3379
# DONNEZAC 33151001 18901
# DONZAC MOURENS 33152001 334
# ETAULIERS 33159001 16283
# BORDEAUX_OBSERVATOIRE 33167001 2191
# FLOUDES AERODROME 33169001 519
# GAURIAGUET ECOLE 33183001 942
# GRIGNOLS 33195001 18995
# GUITRES 33198001 19204
# LE HAILLAN 33200001 1734
# HOURTIN 33203001 21455
# IZON 33207001 4322
# LACANAU 33214002 26220
# LAGORCE 33218001 4582
# LANDERROUAT 33223001 5174
# LANGON MAGASIN DES TABACS 33227001 1509
# LAPOUYADE ECOLE 33230001 973
# LAPOUYADE 33230002 5748
# LATRESNE 33234002 10192
# LEGE-CAP-FERRET 33236001 639
# CAP-FERRET 33236002 26663
# LEGE-BOURG 33236004 6454
# LESPARRE MEDOC 33240001 21734
# LESPARRE-MEDOC RUE MARCOU 33240002 4382
# LES LEVES THOUM 33242001 18964
# LORMONT 33249001 2565
# BORDEAUX-MERIGNAC 33281001 26663
# MERIGNAC BOURRA 33281002 4740
# MIOS VILLA JULIETTE 33284001 365
# MONSEGUR 33289001 8432
# MONSEGUR 33289002 2618
# MORIZES 33294001 2191
# MOULIS 33297001 1095
# MOULON 33298001 3836
# MOULON 33298002 5547
# NAUJAC-SUR-MER 33300001 6971
# NAUJAC-SUR-MER ECOLE 33300002 4565
# NERIGEAN DOMAINE DE CARRERE 33303001 2465
# PAUILLAC ILE DE PATIRAS 33314001 1888
# PAUILLAC-SUD 33314003 9239
# LAFITE 33314004 2296
# PAUILLAC 33314005 22280
# PESSAC MAGONTY 33318001 5720
# PESSAC C DE BOS 33318002 243
# PINEUILH AUX JUSTICES 33324001 5113
# PLASSAC 33325001 12965
# POMEROL 33328001 2495
# MALLE 33337001 2673
# PUJOLS 33343001 2131
# LE PUY 33345001 2312
# RUCH SAE 33361001 243
# SAINT-ANDRE-DE-CUBZAC 33366001 3989
# SAINT-ANTOINE-SUR-L'ISLE BOURG 33373001 4503
# SAINT-BRICE 33379001 4323
# SAINT-CHRISTOLY-MEDOC ECOLE 33383001 456
# SAINT-EMILION CHATEAU SIMARD 33394001 243
# ST EMILION 33394002 10227
# ST GERVAIS 33415001 10013
# SAINTE-HELENE ECOLE 33417001 3132
# ST LAURENT MEDOC 33424001 18716
# ST-LOUBERT 33432001 9652
# ST-LOUBERT 33432002 8694
# ST-MARTIN-DU-BO 33445001 17531
# SAINT PALAIS 33456001 611
# ST-PEY-DE-CASTE 33460001 9434
# SAINT-SAUVEUR AGGLOMERATION 33471001 1613
# ST-SAVIN 33473001 23284
# SAINT-SULPICE-DE-GUILLERAGUES 33481001 4502
# ST SULPICE DE POMMIERS 33482001 7550
# ST-SYMPHORIEN 33484001 26409
# ST-SYMPHORIENJ 33484002 20636
# ST-TROJAN 33486001 2191
# SALAUNES 33494001 22083
# SALLEBOEUF 33496002 1066
# SAUCATS DOMAINE D'ARGILLAS 33501001 4018
# SAUCATS PEYON - SAE 33501002 243
# SAUTERNES 33504001 26663
# SAUVETERRE-DE-G 33506001 21364
# SOULAC 33514001 2648
# SOULAC-SUR-MER 33514002 6850
# SOULAC-SUR-MER 33514003 5993
# SOUSSAC CEIO 33516001 2650
# TAILLECAVAT LA FORET 33520001 2038
# TALENCE 33522001 24653
# TARGON 33523001 16706
# TAURI 33525001 2078
# LE TEICH DOMAINE DE NEZER 33527001 6301
# LE TEMPLE 33528001 15018
# CAZAUX 33529001 26663
# LA TESTE-DE-BUCH 33529003 1795
# LA TESTE-DE-BUCH-LA SALIE 33529004 151
# VENDAYS-MONTALIVE 33540001 19670
# VENSAC DAVID 33541001 21365
# VENSAC LES ARES 33541002 8188
# LE VERDON-SUR-M 33544001 19996
# LE VERDON-SUR-MER-CORDOUAN 33544002 2181
# VIGNONET 33546001 10624
# VIGNONET 33546002 2191
# VILLENAVE D'ORNON-INRA 33550001 26663
# YVRAC AERODROME 33554001 882

# %%
index = 33063001

data_lieu = data_select.loc[
    data_select.index == index
    , 
]

data_lieu.shape
# Out:
# (26663, 6)

# %%
data_date = data_lieu.copy()

data_date[nom_date] = to_datetime(
    data_date[nom_date]
    , format = nom_format
)

data_index = data_date.set_index(nom_date).sort_index()

data_index
# Out:
#                         NOM        LAT       LON    TM    TM
# DATE
# 1950-01-01  BORDEAUX-PAULIN  44.849667 -0.588667   NaN   NaN
# 1950-01-02  BORDEAUX-PAULIN  44.849667 -0.588667   NaN   NaN
# 1950-01-03  BORDEAUX-PAULIN  44.849667 -0.588667   NaN   NaN
# 1950-01-04  BORDEAUX-PAULIN  44.849667 -0.588667   NaN   NaN
# 1950-01-05  BORDEAUX-PAULIN  44.849667 -0.588667   NaN   NaN
# ...                     ...        ...       ...   ...   ...
# 2022-12-27  BORDEAUX-PAULIN  44.849667 -0.588667   8.3  10.0
# 2022-12-28  BORDEAUX-PAULIN  44.849667 -0.588667   8.1  12.0
# 2022-12-29  BORDEAUX-PAULIN  44.849667 -0.588667  11.4  12.0
# 2022-12-30  BORDEAUX-PAULIN  44.849667 -0.588667  10.3  13.1
# 2022-12-31  BORDEAUX-PAULIN  44.849667 -0.588667  11.1  14.1
#
# [26663 rows x 5 columns]

# %% [markdown]
# ## Enregistrer

# %%
data_lieu.to_csv(fichier + '_lieu.csv')
